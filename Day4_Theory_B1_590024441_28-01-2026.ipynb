# %%
#Please explain in simple pseudo code how upper() function is a not a function / method of str class.
# Pseudo Code Explanation
# CLASS str
#     METHOD upper(self)
#         FOR each character in self
#             convert character to uppercase
#         END FOR
#         RETURN new_string
# END CLASS

# %%
# class builtin()
#     function len()
# class str(builtin)

# %%
text = "hello world"
print(text.upper())
# Out:
# HELLO WORLD

# %%
len("python")
# Out:
# 6
