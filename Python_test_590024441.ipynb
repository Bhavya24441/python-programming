# %%
#Ans1-
class Student:
    school_name = "upes"

    def __init__(self, name, age):
        self.name = name
        self.age = age
s1 = Student("Bhavya", 19)
s2= Student("Ashish", 21)

print("School 1:", s1.school_name)
print("School 2", s2.school_name)

print(f"Student 1: {s1.name}, Age {s1.age}")
print(f"Student 2: {s2.name}, Age {s2.age} ")
# Out:
# School 1: upes
# School 2 upes
# Student 1: Bhavya, Age 19
# Student 2: Ashish, Age 21

# %%
#Ans2-

class Employee:
    company = "ABC Ltd"
    def __init__ (self, name, salary):
        self.name = name
        self.salary = salary
    def show_details(self):
        print(f"Company: {Employee.company}, name: {self.name}, salary: {self.salary}")

    @classmethod
    def change_company(cls, new_name):
        cls.company = new_name

e1 = Employee("Bhavya", 2000)
e2 = Employee("Aryan",3000)
print("before change: ")
e1.show_details()
e2.show_details()

Employee.change_company("ABC LTD")
print("After change")
e1.show_details()
e2.show_details()
# Out:
# before change:
# Company: ABC Ltd, name: Bhavya, salary: 2000
# Company: ABC Ltd, name: Aryan, salary: 3000
# After change
# Company: ABC LTD, name: Bhavya, salary: 2000
# Company: ABC LTD, name: Aryan, salary: 3000

# %%
#Ans3-
class MathHelper:
    @staticmethod
    def is_even(num):
        return num%2==0
A1 = MathHelper()
print(A1.is_even(33))
print(A1.is_even(11))
# Out:
# False
# False

# %%
#Ans4-
class BankAccount:
    def __init__(self, name, balance):
        self.name = name
        self.balance = balance
    def deposit(self,amount):
        if amount>0:
            self.balance = amount
        else:
            print("Wrong amount")
    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient balance")
        else:
            self.balance = amount
            print(amount, "Withdraw")
    def show_balance(self):
        print("Current balance:", self.balance)
A1= BankAccount("Bhavya", 3000)
A1.deposit(100)
A1.withdraw(1000)
A1.withdraw(11)
A1.show_balance()
# Out:
# Insufficient balance
# 11 Withdraw
# Current balance: 11

# %%
#Ans5- 
class Student:
    def __init__(self, name):
        self.name = name
    def __name__(self):
        return f"Name of student: {self.name}"
    def __doc__(self):
        print("Thsi is doc")
    def __module__(self):
        print("This is module")

# %%
#Ans6- 
class Product:
    def __init__(self,name,price):
        self.name = name
        self.price = price
    def __str__(self):
        return f"name: {self.name}, price: {self.price}"
    
    def __add__(self,other):
        return self.price+other.price
    def __eq__(self, other):
        return self.price == other.price

p1 = Product("Laptop", 50000)
p2 = Product("Phone", 30000)
p3 = Product("Tablet", 50000)

print(p1)
print(p1 + p2)
print(p1 == p2)
# Out:
# name: Laptop, price: 50000
# 80000
# False
