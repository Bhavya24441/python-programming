# %% [markdown]
# Question:
#
# Create a class Car with attributes brand and speed. Add a method to display details.

# %%
#Solution

class car:
    def __init__(self, brand, speed):
        self.brand = brand
        self.speed = speed
    def display(self):
        print(self.brand, self.speed)
c= car("BMW", 120)
c.display()
# Out:
# BMW 120

# %% [markdown]
# Question:
#
# Create a class Employee that counts total employees created.

# %%
#Solution
class Employee:
    count = 0
    def __init__(self,name):
        self.name = name 
        Employee.count +=1
e1 = Employee("A")
e2 = Employee("B")
print(Employee.count)
# Out:
# 2

# %% [markdown]
# Question:
#
# Create a base class Animal and a child class Dog that adds a method bark.

# %%
#Solution:
class Animal:
    def speak(self):
        print("Animal speaks")
class Dog(Animal):
    def bark(self):
        print("Dog barks")
d= Dog()
d.speak()
d.bark()
# Out:
# Animal speaks
# Dog barks

# %% [markdown]
# Question:
#
# Create a class Account with private balance and methods to access it.

# %%
#Solution
class Account:
    def __init__(self, balance):\
    self.__balance = balance
    
    def get_balance(self):
        return self.__balance
a = Account(1000)
print(a.get_balance())
# Out:
# 1000

# %% [markdown]
# Question
# Create two classes Bird and Fish with same method move but different outputs

# %%
class Bird:
    def move(self):
        print("Flying")
class Fish:
    def move(self):
        print("Swimming")
b = Bird()
f = Fish()
b.move()
f.move()
# Out:
# Flying
# Swimming
