# %% [markdown]
# # Experiment 3: Conditional Statements

# %% [markdown]
# 1. Check whether a given number is divisible by 3 and 5 both.

# %%
#Solution:
n = int(input("Enter a number: "))
if n % 3 == 0 and n %5 == 0:
    print("The entered number is divisible by 3 and 5 both")
else:
    print("The entered number is not divisible by 3 and 5 both")
# Out:
# The entered number is not divisible by 3 and 5 both

# %% [markdown]
# 2. Check whether a given number is multiple of five or not.

# %%
#Solution
n = int(input("Enter a number: "))
if n % 5 == 0:
    print("The entered number is a nultiple of 5")
else:
    print("The enterd number is not a multiple of 5")
# Out:
# The entered number is a nultiple of 5

# %% [markdown]
# 3. Find the greatest among two numbers. If numbers are equal than print
# “numbers are equal”.

# %%
#Solution
a = int(input("Enter a number: "))
b = int(input("Enter a number: "))
if a > b:
    print(a,"is greater then the second number")
elif b < a:
    print(b,"is greater then the first number ")
else:
    print("Both the numbers are equal")
# Out:
# Both the numbers are equal

# %% [markdown]
# 4. Find the greatest among three numbers assuming no two values are same.

# %%
#Solution

a = int(input("Enter a number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print(a, "is the greatest number")
elif b>a and b>c:
    print(b, "is the greatest number")
else:
    print(c,"is the greatest number")
# Out:
# 5 is the greatest number

# %% [markdown]
# 5. Check whether the quadratic equation has real roots or imaginary roots.
# Display the roots.

# %%
#Solution
a = int(input("Enter a:"))
b = int(input("Enter b: "))
c = int(input("Enter a number:"))


d = b*b - 4*a*c

if d > 0:
    r1 = (-b + d**0.5) / (2*a)  #Roots are real and different
    r2 = (-b - d**0.5) / (2*a)
    print("The roots are real and different ")
    print(r1)
    print(r2)

    
elif d == 0:
    r = -b / (2*a) #Roots are real and equal
    print("Roots are real and equal")
    print(r)

else:
    print("Roots are imaginary")

#else roots are imaginary
# Out:
# Roots are imaginary

# %% [markdown]
# 6. Find whether a given year is a leap year or not.

# %%
#solution:
year = int(input("Enter a year: "))
if(year % 400 == 0) or (year % 4 ==0 and year% 100 != 0):
    print(year,"is a leap year")
else:
    print(year,"is not a leap year")
# Out:
# 2026 is not a leap year

# %% [markdown]
# 7. Write a program which takes any date as input and display next date of the
# calendar e.g.
# I/P: day=20 month=9 year=2005
# O/P: day=21 month=9 year 2005

# %%
day = int(input("Enter a day: "))
month = int(input("Enter a month"))
year = int(input("Enter a year: "))

if ( year % 400 == 0) or (year % 4 == 0 and year % 100 !=0):
    leap = True
else:
    leap = False


if month == 1 or month == 3 or month ==5 or month == 7 or month ==  8 or month == 10 or month == 12:
    max_days = 31
elif month == 4 or month ==  6 or month == 9 or month == 11 :
    max_days = 30
elif month == 2:
    if leap:
        max_days = 29
    else:
        max_days= 28

if day < max_days:
    day = day +1 
else:
    day =1 
    if month < 12:
        month = month +1 
    else:
        month =  1 
        year = year + 1

print("Next date is : ")
print("day =", day,"month = ", month," year= ", year)
# Out:
# Next date is :
# day = 3 month =  2  year=  2025

# %% [markdown]
# 8. Print the grade sheet of a student for the given range of cgpa. Scan marks of
# five subjects and calculate the percentage.
# CGPA=percentage/10
# CGPA range:
# 0 to 3.4 -> F
# 3.5 to 5.0->C+
# 5.1 to 6->B
# 6.1 to 7-> B+
# 7.1 to 8-> A
# 8.1 to 9->A+
# 9.1 to 10-> O (Outstanding)
# Sample Gradesheet
# Name: Rohit Sharma
# Roll Number: R17234512 SAPID: 50005673
# Sem: 1 Course: B.Tech. CSE AI&ML
# Subject name: Marks
# PDS: 70
# Python: 80
# Chemistry: 90
# English: 60
# Physics: 50
# Percentage: 70%
# CGPA:7.0
# Grade:  A

# %%
name = input("Enter name: ")
roll = int(input("Enter roll number: "))
sap_id = int(input("Enter your sap id: "))
sem = int(input("Enter your sem:"))
course = input("Enter your course:")

print("Enter marks of 5 subjects : ")
m1 = int(input("PDS: "))
m2 = int(input("Python"))
m3= int(input("Chemistry"))
m4 = int(input("English: "))
m5= int(input("Physics: "))

total = m1+ m2 + m3 + m4 + m5
percentage = total / 5
cgpa = percentage / 10


if cgpa >=0 and cgpa <=3.4:
    grade = "F"
elif cgpa >= 3.5 and cgpa <= 5.0:
    grade = "C+"
elif cgpa >= 5.1 and cgpa <= 6.0:
    grade = "B"
elif cgpa>= 6.1 and cgpa <7:
    grade = "B+"
elif cgpa >=7.1 and cgpa <=8:
    grade = "A"
elif cgpa >=8.1 and cgpa<=9.0:
    grade = "A+"
elif cgpa>=9.1 and cgpa <= 10:
    grade= "O(outstanding)"

print("Grade sheet")
print("Name: ", name)
print("Roll number:", roll, "Sap id : ", sap_id )
print("Sem: ", sem, "Course: ", course)

print("Subject name: marks")
print("PDS", m1)
print("Python", m2)
print("Chemistry:", m3)
print("English: ", m4 )
print("Physics:", m5 )


print("Percentage:", percentage, "%")
print("CGPA", cgpa)
